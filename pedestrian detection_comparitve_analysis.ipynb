# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.103-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.103-py3-none-any.whl (994 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 25.5 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.103 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["OPENCV_NUM_THREADS"] = "0"  # Fix for OpenCV threading issue

import torch
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
from PIL import Image
import shutil
import yaml
from pathlib import Path
from sklearn.model_selection import train_test_split
from ultralytics import YOLO
import cv2
import torch.nn as nn
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator, RPNHead
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.ops import MultiScaleRoIAlign
from torchvision.transforms import functional as FT
from torch.utils.data import Dataset
import torch.optim as optim
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Configuration
KITTI_BASE_DIR = '/kaggle/input/kitti-dataset'
IMAGE_DIR = Path(KITTI_BASE_DIR) / 'data_object_image_2' / 'training' / 'image_2'
LABEL_DIR = Path(KITTI_BASE_DIR) / 'data_object_label_2' / 'training' / 'label_2'
TRAIN_DIR = Path('train')
VALID_DIR = Path('valid')
LABELS_DIR = Path('labels_with_dont_care')
CLASSES = ['Car', 'Van', 'Truck', 'Pedestrian', 'Person_sitting', 'Cyclist', 'Tram', 'Misc', 'DontCare']
CLAZZ_NUMBERS = {name: idx for idx, name in enumerate(CLASSES)}
IMG_SIZE = 640
BATCH_SIZE = 16
EPOCHS = 25
MODEL_PATH = 'hybrid_yolo_frcnn.h5'  # Explicitly .h5

# Create directories
for folder in [TRAIN_DIR, VALID_DIR, LABELS_DIR]:
    folder.mkdir(exist_ok=True, parents=True)

# Data Preparation
def convert_bbox_to_yolo(bbox, size):
    dw, dh = 1.0 / size[0], 1.0 / size[1]
    x_center = (bbox[0] + bbox[1]) / 2.0
    y_center = (bbox[2] + bbox[3]) / 2.0
    width = bbox[1] - bbox[0]
    height = bbox[3] - bbox[2]
    return (x_center * dw, y_center * dh, width * dw, height * dh)

def parse_kitti_label_file(lbl_path, img_path):
    with open(lbl_path, 'r', encoding='utf-8') as file:
        lines = file.read().strip().split('\n')
    
    yolo_labels = []
    img_size = Image.open(img_path).size
    
    for line in lines:
        parts = line.split()
        if not parts or parts[0] not in CLAZZ_NUMBERS:
            continue
        try:
            bbox = (float(parts[4]), float(parts[5]), float(parts[6]), float(parts[7]))
            yolo_label = (CLAZZ_NUMBERS[parts[0]], *convert_bbox_to_yolo(bbox, img_size))
            yolo_labels.append(yolo_label)
        except (ValueError, IndexError) as e:
            print(f"Error processing line: {e}")
            continue
    
    return yolo_labels

def prepare_dataset():
    print("\nPreparing KITTI Dataset")
    image_paths = sorted(IMAGE_DIR.glob('*.png'))
    label_paths = sorted(LABEL_DIR.glob('*.txt'))

    for img_path in image_paths:
        lbl_path = LABEL_DIR / f"{img_path.stem}.txt"
        if lbl_path.exists():
            yolo_labels = parse_kitti_label_file(lbl_path, img_path)
            with open(LABELS_DIR / f"{img_path.stem}.txt", 'w') as lf:
                for lbl in yolo_labels:
                    lf.write(" ".join(f"{val:.6f}" for val in lbl) + "\n")

    labels_for_images = [(img, LABELS_DIR / f"{img.stem}.txt") 
                        for img in image_paths if (LABELS_DIR / f"{img.stem}.txt").exists()]
    
    train_pairs, valid_pairs = train_test_split(labels_for_images, test_size=0.1, random_state=42)

    for folder in [TRAIN_DIR, VALID_DIR]:
        for sub in ['images', 'labels']:
            (folder / sub).mkdir(exist_ok=True, parents=True)

    for img_path, lbl_path in train_pairs:
        shutil.copy(img_path, TRAIN_DIR / 'images' / img_path.name)
        shutil.copy(lbl_path, TRAIN_DIR / 'labels' / lbl_path.name)
    for img_path, lbl_path in valid_pairs:
        shutil.copy(img_path, VALID_DIR / 'images' / img_path.name)
        shutil.copy(lbl_path, VALID_DIR / 'labels' / lbl_path.name)

    with open('data.yaml', 'w') as f:
        yaml.dump({
            'train': str((TRAIN_DIR / 'images').resolve()),
            'val': str((VALID_DIR / 'images').resolve()),
            'names': CLASSES,
            'nc': len(CLASSES)
        }, f)

# %%
import torch
import torchvision
import torchvision.transforms as T
from PIL import Image
from torchvision.models.detection.rpn import AnchorGenerator, RPNHead
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.ops import MultiScaleRoIAlign
import numpy as np

class FasterRCNNFromScratch(torch.nn.Module):
    def __init__(self, num_classes=9):
        super(FasterRCNNFromScratch, self).__init__()
        self.backbone = resnet_fpn_backbone('resnet50', pretrained=True)
        anchor_sizes = ((32,), (64,), (128,), (256,), (512,))
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_sizes)
        self.rpn = torch.nn.Module()  # Namespace change
        self.rpn.anchor_generator = AnchorGenerator(anchor_sizes, aspect_ratios)
        out_channels = self.backbone.out_channels
        self.rpn.head = RPNHead(out_channels, self.rpn.anchor_generator.num_anchors_per_location()[0])
        self.roi_heads = torch.nn.Module()  # Namespace change
        self.roi_heads.box_roi_pool = MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=7, sampling_ratio=2)
        representation_size = 1024
        self.roi_heads.box_head = torch.nn.Sequential(
            torch.nn.Flatten(),
            torch.nn.Linear(out_channels * 7 * 7, representation_size),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(representation_size, representation_size),  # Match fc6, fc7
            torch.nn.ReLU(inplace=True)
        )
        self.roi_heads.box_predictor = FastRCNNPredictor(representation_size, num_classes)

    def forward(self, images, targets=None):
        # Implementation remains similar but uses self.rpn and self.roi_heads
        features = self.backbone(images)
        proposals, proposal_losses = self.rpn.head(images, features, targets)
        box_features = self.roi_heads.box_roi_pool(features, proposals, [images.shape[-2:]])
        box_features = self.roi_heads.box_head(box_features)
        class_logits, box_regression = self.roi_heads.box_predictor(box_features)
        
        result = []
        losses = {}
        if self.training and targets:
            losses.update(proposal_losses)
        else:
            boxes, scores, labels = self.postprocess_detections(class_logits, box_regression, proposals, [images.shape[-2:]])
            result = [{'boxes': boxes[i], 'labels': labels[i], 'scores': scores[i]} for i in range(len(boxes))]
        return result if not self.training else losses

    def postprocess_detections(self, class_logits, box_regression, proposals, image_shapes):
        boxes = []
        scores = []
        labels = []
        for p, cl, br in zip(proposals, class_logits, box_regression):
            scores_batch = torch.softmax(cl, dim=-1)
            max_scores, max_labels = scores_batch.max(dim=-1)
            keep = max_scores > 0.3
            boxes.append(p[keep])
            scores.append(max_scores[keep])
            labels.append(max_labels[keep])
        return boxes, scores, labels

def load_faster_rcnn(num_classes=9):
    return FasterRCNNFromScratch(num_classes=num_classes)

# %%
class ImageList(object):
    """
    Structure that holds a list of images (of possibly varying sizes) as a single tensor.
    This works by padding the images to the same size.
    """
    def __init__(self, tensors, image_sizes):
        self.tensors = tensors
        self.image_sizes = image_sizes

    def to(self, device):
        cast_tensor = self.tensors.to(device)
        return ImageList(cast_tensor, self.image_sizes)

# Hybrid Model
class HybridModel(tf.keras.Model):
    def __init__(self, num_classes=len(CLASSES)):
        super(HybridModel, self).__init__()
        self.yolo = YOLO('yolov8n.pt').model
        self.yolo.requires_grad_(False)
        self.rpn_conv = tf.keras.Sequential([
            layers.Conv2D(512, 3, padding='same', activation='relu'),
            layers.Conv2D(256, 3, padding='same', activation='relu')
        ])
        self.rpn_cls = layers.Conv2D(9, 1, activation='sigmoid')
        self.rpn_reg = layers.Conv2D(9 * 4, 1)
        self.roi_pooling = layers.AveragePooling2D(pool_size=(14, 14))
        self.cls_head = tf.keras.Sequential([
            layers.Dense(1024, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ])
        self.reg_head = tf.keras.Sequential([
            layers.Dense(1024, activation='relu'),
            layers.Dense(num_classes * 4)
        ])

    def call(self, inputs, training=False):
        img_np = tf.cast(inputs, tf.float32).numpy()
        with torch.no_grad():
            yolo_features = self.yolo(torch.from_numpy(img_np).to('cpu'))
        features_tf = tf.convert_to_tensor(yolo_features.detach().cpu().numpy())
        x = self.rpn_conv(features_tf)
        rpn_scores = self.rpn_cls(x)
        rpn_boxes = self.rpn_reg(x)
        proposals = self.generate_proposals(rpn_boxes, rpn_scores)
        pooled_features = self.roi_pooling(proposals)
        cls_output = self.cls_head(pooled_features)
        reg_output = self.reg_head(pooled_features)
        return rpn_scores, rpn_boxes, cls_output, reg_output

    def generate_proposals(self, rpn_boxes, rpn_scores, top_n=100):
        scores = tf.reshape(rpn_scores, [-1])
        boxes = tf.reshape(rpn_boxes, [-1, 4])
        _, indices = tf.math.top_k(scores, k=top_n)
        proposals = tf.gather(boxes, indices)
        proposals = tf.stack([
            proposals[:, 0] / 20.0,
            proposals[:, 1] / 20.0,
            tf.exp(proposals[:, 2]),
            tf.exp(proposals[:, 3])
        ], axis=1)
        return tf.expand_dims(proposals, 0)

# Data Generator
class HybridDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_dir, label_dir, batch_size=16, img_size=640, shuffle=True):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
        self.label_files = [f.replace('.png', '.txt') for f in self.image_files]
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        images = np.zeros((len(batch_indices), self.img_size, self.img_size, 3))
        targets = np.zeros((len(batch_indices), 100, 5 + len(CLASSES)))
        
        for i, idx in enumerate(batch_indices):
            img_path = os.path.join(self.image_dir, self.image_files[idx])
            img = Image.open(img_path).convert('RGB').resize((self.img_size, self.img_size))
            images[i] = np.array(img) / 255.0
            label_path = os.path.join(self.label_dir, self.label_files[idx])
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    for obj_idx, line in enumerate(lines[:100]):
                        parts = line.strip().split()
                        if len(parts) < 5:
                            continue
                        class_id = int(float(parts[0]))
                        targets[i, obj_idx, :4] = list(map(float, parts[1:5]))
                        targets[i, obj_idx, 4] = 1
                        targets[i, obj_idx, 5 + class_id] = 1
        return images, targets

    def on_epoch_end(self):
        self.indices = np.arange(len(self.image_files))
        if self.shuffle:
            np.random.shuffle(self.indices)

# Loss Function
class HybridLoss(tf.keras.losses.Loss):
    def __init__(self, num_classes):
        super().__init__()
        self.rpn_cls_loss = tf.keras.losses.BinaryCrossentropy()
        self.rpn_reg_loss = tf.keras.losses.Huber()
        self.rcnn_cls_loss = tf.keras.losses.CategoricalCrossentropy()
        self.rcnn_reg_loss = tf.keras.losses.Huber()

    def call(self, y_true, y_pred):
        true_rpn_cls = y_true[..., 4]
        true_rpn_reg = y_true[..., :4]
        true_rcnn_cls = y_true[..., 5:]
        true_rcnn_reg = y_true[..., :4]
        pred_rpn_cls, pred_rpn_reg, pred_rcnn_cls, pred_rcnn_reg = y_pred
        rpn_cls_loss = self.rpn_cls_loss(true_rpn_cls, pred_rpn_cls)
        rpn_reg_loss = self.rpn_reg_loss(true_rpn_reg, pred_rpn_reg)
        rcnn_cls_loss = self.rcnn_cls_loss(true_rcnn_cls, pred_rcnn_cls)
        rcnn_reg_loss = self.rcnn_reg_loss(true_rcnn_reg, pred_rcnn_reg)
        return rpn_cls_loss + rpn_reg_loss + rcnn_cls_loss + rcnn_reg_loss

# Training Function
def train_model():
    prepare_dataset()
    model = HybridModel(num_classes=len(CLASSES))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss=HybridLoss(len(CLASSES)),
        metrics=['accuracy']
    )
    train_gen = HybridDataGenerator(
        str(TRAIN_DIR / 'images'),
        str(TRAIN_DIR / 'labels'),
        BATCH_SIZE,
        IMG_SIZE
    )
    val_gen = HybridDataGenerator(
        str(VALID_DIR / 'images'),
        str(VALID_DIR / 'labels'),
        BATCH_SIZE,
        IMG_SIZE,
        shuffle=False
    )
    # Save weights only in .h5 format to avoid .keras requirement
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        MODEL_PATH,
        save_best_only=True,
        save_weights_only=True  # Save weights in HDF5 format
    )
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=[
            checkpoint,
            tf.keras.callbacks.ReduceLROnPlateau(patience=3),
            tf.keras.callbacks.EarlyStopping(patience=5)
        ]
    )
    return history



# Dataset Class
class KITTIDataset(Dataset):
    def __init__(self, image_dir, label_dir, transform=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transform = transform
        self.image_filenames = sorted(os.listdir(image_dir))
        self.label_filenames = sorted(os.listdir(label_dir))
        self.CLASS_MAPPING = {
            "Pedestrian": 1, "Car": 2, "Cyclist": 3, "Truck": 4,
            "Van": 5, "Tram": 6, "Misc": 7, "Person_sitting": 8
        }

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_filenames[idx])
        image = Image.open(image_path).convert("RGB")
        label_path = os.path.join(self.label_dir, self.label_filenames[idx])
        boxes = []
        labels = []
        with open(label_path, "r") as f:
            lines = f.readlines()
            for line in lines:
                parts = line.strip().split()
                class_name = parts[0]
                if class_name not in self.CLASS_MAPPING:
                    continue
                class_label = self.CLASS_MAPPING[class_name]
                x_min, y_min, x_max, y_max = map(float, parts[4:8])
                boxes.append([x_min, y_min, x_max, y_max])
                labels.append(class_label)
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        target = {"boxes": boxes, "labels": labels}
        if self.transform:
            image = self.transform(image)
        return image, target

def collate_fn(batch):
    images, targets = zip(*batch)
    return list(images), list(targets)

# Training Functions
def train_yolo():
    yolo_model = YOLO("yolov10n.pt")
    yolo_model.train(data="data.yaml", epochs=25, batch=16, imgsz=640)
    yolo_model.save("trained_yolov10.pt")

def train_faster_rcnn(dataloader):
    model = load_faster_rcnn(num_classes=9)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)
    model.train()
    for batch_idx, batch in enumerate(dataloader):
        images, targets = batch
        if len(images) == 0 or len(targets) == 0:
            continue
        processed_images = [FT.to_tensor(img).to(device) if isinstance(img, Image.Image) else img.to(device) for img in images]
        processed_targets = [{k: v.to(device) for k, v in t.items()} for t in targets if isinstance(t, dict)]
        if len(processed_images) == 0 or len(processed_targets) == 0:
            continue
        optimizer.zero_grad()
        loss_dict = model(processed_images, processed_targets)
        losses = sum(loss for loss in loss_dict.values())
        losses.backward()
        optimizer.step()
    torch.save(model.state_dict(), "trained_faster_rcnn.pth")
    print("Faster R-CNN training completed!")

# Detection Functions
def detect_with_faster_rcnn(image, model):
    transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])  # Use full path or import correctly
    img_tensor = transform(image).unsqueeze(0)  # Add batch dimension
    model.eval()
    with torch.no_grad():
        outputs = model(img_tensor)
    return outputs

def detect_with_yolo(image_path, yolo_model):
    results = yolo_model(image_path)
    return results[0].boxes.data.cpu().numpy()


def merge_detections(yolo_detections, frcnn_detections, iou_threshold=0.5):
    final_detections = []
    for yolo_det in yolo_detections:
        best_iou = 0
        for frcnn_det in frcnn_detections[0]['boxes']:
            iou = compute_iou(yolo_det[:4], frcnn_det.cpu().numpy())
            if iou > best_iou:
                best_iou = iou
        if best_iou < iou_threshold:
            final_detections.append(yolo_det)
    for frcnn_det in frcnn_detections[0]['boxes']:
        final_detections.append(frcnn_det.cpu().numpy())
    return np.array(final_detections)

def detect_pedestrians(image_path, yolo_model, frcnn_model):
    image = Image.open(image_path).convert("RGB")
    yolo_detections = detect_with_yolo(image_path, yolo_model)
    frcnn_detections = detect_with_faster_rcnn(image, frcnn_model)
    return merge_detections(yolo_detections, frcnn_detections)

def save_hybrid_model(yolo_model, frcnn_model):
    hybrid_model = {'yolo': yolo_model.model.state_dict(), 'frcnn': frcnn_model.state_dict()}
    torch.save(hybrid_model, MODEL_PATH)

# %%
prepare_dataset()
# Out:
# Preparing KITTI Dataset

# %%
# Load the hybrid model correctly
def load_hybrid_model(yolo_path, frcnn_path):
    # Load YOLO
    from ultralytics import YOLO
    yolo_model = YOLO(yolo_path)
    
    # Instantiate Faster R-CNN and load state dict
    frcnn_model = FasterRCNNFromScratch(num_classes=9)  # Match your num_classes
    state_dict = torch.load(frcnn_path) if frcnn_path.endswith('.pth') else torch.load('hybrid_yolo_frcnn.h5')['frcnn']
    frcnn_model.load_state_dict(state_dict)
    
    return {'yolo': yolo_model, 'frcnn': frcnn_model}

# %%
import time
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn, ssdlite320_mobilenet_v3_large
from ultralytics import YOLO
import numpy as np
from PIL import Image
import os
from pathlib import Path

# Define paths from your code
VALID_DIR = Path('valid')  # Validation directory from your setup
CLASSES = ['Car', 'Van', 'Truck', 'Pedestrian', 'Person_sitting', 'Cyclist', 'Tram', 'Misc', 'DontCare']
CLAZZ_NUMBERS = {name: idx for idx, name in enumerate(CLASSES)}

# Load YOLOv8
yolo_v8 = YOLO('yolov8n.pt')  # Nano version for speed; use 'yolov8s.pt' or 'yolov8m.pt' for more accuracy

# Load SSD with MobileNetV2 backbone
ssd_model = ssdlite320_mobilenet_v3_large(pretrained=True)
ssd_model.eval()

# Load standalone Faster R-CNN
frcnn_model = fasterrcnn_resnet50_fpn(pretrained=True)
frcnn_model.eval()

# Load your hybrid model (assuming it's saved as in your code)
hybrid_model = torch.load('/kaggle/input/hybrid_ped_det/tensorflow2/default/1/hybrid_yolo_frcnn.h5')  # Adjust loading based on your save format
# If your hybrid model is split, load YOLO and FRCNN separately as per your save_hybrid_model function
yolo_model = YOLO('/kaggle/input/pedestrian-models/pytorch/default/1/trained_yolov10.pt')
frcnn_custom = hybrid_model['frcnn']  # Adjust based on your hybrid structure

# %%
# Get validation image and label paths
val_image_paths = [str(p) for p in VALID_DIR.glob('images/*.png')]
val_label_paths = [str(p) for p in VALID_DIR.glob('labels/*.txt')]

# Function to load ground truth in YOLO format
def load_gt(label_path):
    with open(label_path, 'r') as f:
        lines = f.readlines()
    gt_boxes = []
    gt_labels = []
    for line in lines:
        parts = line.strip().split()
        class_id = int(float(parts[0]))
        if class_id == CLAZZ_NUMBERS['Pedestrian']:
            # YOLO format: [x_center, y_center, width, height]
            bbox = list(map(float, parts[1:5]))
            gt_boxes.append(bbox)
            gt_labels.append(1)  # 1 for Pedestrian
        else:
            gt_boxes.append(list(map(float, parts[1:5])))
            gt_labels.append(0)  # 0 for non-Pedestrian
    return gt_boxes, gt_labels

# %%
def compute_iou(box1, box2, yolo_format=True):
    """Compute IoU between two boxes."""
    if yolo_format:  # Convert YOLO [x_center, y_center, w, h] to [x1, y1, x2, y2]
        x1 = box1[0] - box1[2] / 2
        y1 = box1[1] - box1[3] / 2
        x2 = box1[0] + box1[2] / 2
        y2 = box1[1] + box1[3] / 2
        box1 = [x1, y1, x2, y2]
        
        x1 = box2[0] - box2[2] / 2
        y1 = box2[1] - box2[3] / 2
        x2 = box2[0] + box2[2] / 2
        y2 = box2[1] + box2[3] / 2
        box2 = [x1, y1, x2, y2]
    
    # Intersection coordinates
    x_left = max(box1[0], box2[0])
    y_top = max(box1[1], box2[1])
    x_right = min(box1[2], box2[2])
    y_bottom = min(box1[3], box2[3])
    
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    
    intersection = (x_right - x_left) * (y_bottom - y_top)
    area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = area1 + area2 - intersection
    return intersection / union if union > 0 else 0.0

import numpy as np

def compute_ap(pred_scores, pred_boxes, pred_labels, gt_boxes, gt_labels, iou_threshold=0.5):
    """
    Compute Average Precision (AP) for a set of predictions.
    
    Args:
        pred_scores (np.ndarray): Confidence scores of predictions.
        pred_boxes (list): Predicted bounding boxes [x1, y1, x2, y2].
        pred_labels (np.ndarray): Predicted class labels.
        gt_boxes (list): Ground truth bounding boxes [x1, y1, x2, y2].
        gt_labels (np.ndarray): Ground truth class labels.
        iou_threshold (float): IoU threshold for a true positive.
    
    Returns:
        float: Average Precision score.
    """
    if len(pred_boxes) == 0 or len(gt_boxes) == 0:
        return 0.0 if len(gt_boxes) > 0 else 1.0
    
    # Sort predictions by confidence scores in descending order
    indices = np.argsort(-pred_scores)
    pred_scores = pred_scores[indices]
    pred_boxes = [pred_boxes[i] for i in indices]
    pred_labels = pred_labels[indices]
    
    # Initialize TP and FP arrays
    tp = np.zeros(len(pred_boxes))
    fp = np.zeros(len(pred_boxes))
    gt_matched = set()  # Track matched ground truth boxes
    
    # Match predictions to ground truth
    for i, (pred_box, pred_label) in enumerate(zip(pred_boxes, pred_labels)):
        max_iou = 0.0
        max_idx = -1
        # Find best matching ground truth box
        for j, (gt_box, gt_label) in enumerate(zip(gt_boxes, gt_labels)):
            if j in gt_matched or pred_label != gt_label:
                continue
            iou = compute_iou(pred_box, gt_box)  # Assume compute_iou is defined
            if iou > max_iou:
                max_iou = iou
                max_idx = j
        # Assign TP or FP based on IoU threshold
        if max_iou >= iou_threshold and max_idx >= 0:
            tp[i] = 1
            gt_matched.add(max_idx)
        else:
            fp[i] = 1
    
    # Compute precision and recall
    tp_cumsum = np.cumsum(tp)
    fp_cumsum = np.cumsum(fp)
    precision = tp_cumsum / (tp_cumsum + fp_cumsum + 1e-6)
    recall = tp_cumsum / (len(gt_boxes) + 1e-6)
    
    # 11-point interpolation for AP
    ap = 0.0
    for t in np.arange(0.0, 1.1, 0.1):
        if np.any(recall >= t):
            ap += np.max(precision[recall >= t]) / 11.0
    
    return ap

def compute_iou(box1, box2):
    """
    Compute Intersection over Union (IoU) between two boxes.
    
    Args:
        box1, box2: [x1, y1, x2, y2] coordinates.
    
    Returns:
        float: IoU value.
    """
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    
    intersection = max(0, x2 - x1) * max(0, y2 - y1)
    area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = area1 + area2 - intersection
    
    return intersection / union if union > 0 else 0.0
    
def evaluate_model(model, image_paths, label_paths, model_type='hybrid'):
    all_aps = []
    pedestrian_aps = []
    inference_times = []
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    for img_path, lbl_path in zip(image_paths, label_paths):
        start_time = time.time()
        image = Image.open(img_path).convert('RGB')
        
        if model_type == 'hybrid':
            # Use your detect_pedestrians function
            detections = detect_pedestrians(img_path, yolo_model, frcnn_custom)
            pred_boxes = detections[:, :4]  # [x1, y1, x2, y2]
            pred_scores = detections[:, 4]
            pred_labels = detections[:, 5].astype(int)
        
        elif model_type == 'yolo':
            results = yolo_v8(img_path)
            detections = results[0].boxes.data.cpu().numpy()
            pred_boxes = detections[:, :4]  # [x1, y1, x2, y2]
            pred_scores = detections[:, 4]
            pred_labels = detections[:, 5].astype(int)
        
        elif model_type in ['ssd', 'frcnn']:
            transform = torchvision.transforms.ToTensor()
            img_tensor = transform(image).unsqueeze(0).to(device)
            model.to(device)
            with torch.no_grad():
                outputs = model(img_tensor)
            pred_boxes = outputs[0]['boxes'].cpu().numpy()
            pred_scores = outputs[0]['scores'].cpu().numpy()
            pred_labels = outputs[0]['labels'].cpu().numpy() - 1  # Adjust for 0-based indexing
        
        inference_time = time.time() - start_time
        inference_times.append(inference_time)
        
        # Load ground truth
        gt_boxes, gt_labels = load_gt(lbl_path)
        
        # Compute overall mAP
        all_ap = compute_ap(np.array([1 if l >= 0 else 0 for l in gt_labels]), pred_scores, pred_boxes, gt_boxes)
        all_aps.append(all_ap)
        
        # Compute pedestrian-specific mAP
        pedestrian_gt_indices = [i for i, l in enumerate(gt_labels) if l == 1]
        pedestrian_pred_indices = [i for i, l in enumerate(pred_labels) if l == CLAZZ_NUMBERS['Pedestrian']]
        if pedestrian_gt_indices or pedestrian_pred_indices:
            pedestrian_true = np.array([1 if i in pedestrian_gt_indices else 0 for i in range(len(gt_labels))])
            pedestrian_scores = np.zeros(len(pred_labels))
            pedestrian_boxes = []
            for i, idx in enumerate(pedestrian_pred_indices):
                pedestrian_scores[idx] = pred_scores[idx]
                pedestrian_boxes.append(pred_boxes[idx])
            pedestrian_ap = compute_ap(pedestrian_true, pedestrian_scores, pedestrian_boxes, [gt_boxes[i] for i in pedestrian_gt_indices])
            pedestrian_aps.append(pedestrian_ap)
        else:
            pedestrian_aps.append(0.0 if pedestrian_gt_indices else 1.0)
    
    mAP = np.mean(all_aps)
    pedestrian_mAP = np.mean(pedestrian_aps)
    avg_inference_time = np.mean(inference_times)
    fps = 1 / avg_inference_time if avg_inference_time > 0 else 0
    
    return mAP, pedestrian_mAP, avg_inference_time, fps

# %%
yolo_mAP, yolo_ped_mAP, yolo_time, yolo_fps = evaluate_model(yolo_v8, val_image_paths, val_label_paths, model_type='yolo')

# Evaluate SSD
ssd_mAP, ssd_ped_mAP, ssd_time, ssd_fps = evaluate_model(ssd_model, val_image_paths, val_label_paths, model_type='ssd')

# Evaluate Faster R-CNN
frcnn_mAP, frcnn_ped_mAP, frcnn_time, frcnn_fps = evaluate_model(frcnn_model, val_image_paths, val_label_paths, model_type='frcnn')
# Out:
# image 1/1 /kaggle/working/valid/images/003620.png: 224x640 12 Cars, 2 Vans, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002845.png: 224x640 5 Cars, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001421.png: 224x640 1 Pedestrian, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007065.png: 224x640 6 Cars, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002345.png: 224x640 7 Cars, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001922.png: 224x640 3 Cars, 1 Truck, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007119.png: 224x640 3 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006358.png: 224x640 5 Cars, 1 DontCare, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001634.png: 224x640 10 Cars, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003541.png: 224x640 10 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004796.png: 224x640 1 Car, 2 Trucks, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001897.png: 224x640 5 Cars, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007091.png: 224x640 7 Cars, 1 DontCare, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000233.png: 224x640 2 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000037.png: 224x640 4 Cars, 1 Truck, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003885.png: 224x640 6 Cars, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000457.png: 224x640 2 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001701.png: 224x640 11 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007398.png: 224x640 4 Cars, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006007.png: 224x640 11 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001512.png: 224x640 13 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000773.png: 224x640 1 Car, 1 Cyclist, 2 Trams, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006589.png: 224x640 14 Cars, 3 Vans, 10.0ms
# Speed: 1.3ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004961.png: 224x640 4 Cars, 1 Misc, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003103.png: 224x640 5 Cars, 1 Van, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000132.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000065.png: 224x640 4 Person_sittings, 4 Trams, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006309.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004378.png: 224x640 9 Cars, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005400.png: 224x640 4 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003552.png: 224x640 1 Car, 2 Vans, 1 Pedestrian, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003038.png: 224x640 1 Car, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002465.png: 224x640 9 Cars, 1 Van, 2 Pedestrians, 2 Cyclists, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005434.png: 224x640 3 Pedestrians, 3 Trams, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006312.png: 224x640 8 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002906.png: 224x640 1 Pedestrian, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001864.png: 224x640 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006538.png: 224x640 5 Cars, 2 DontCares, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003077.png: 224x640 1 Car, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003946.png: 224x640 2 Cars, 1 Van, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005427.png: 224x640 10 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000500.png: 224x640 11 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003025.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002680.png: 224x640 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002119.png: 224x640 7 Cars, 1 DontCare, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001608.png: 224x640 3 Cars, 1 Van, 2 Pedestrians, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005476.png: 224x640 4 Cars, 1 Van, 1 Misc, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007367.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007124.png: 224x640 7 Cars, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001335.png: 224x640 2 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006182.png: 224x640 3 Cars, 1 DontCare, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002415.png: 224x640 6 Cars, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000408.png: 224x640 7 Cars, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001768.png: 224x640 1 Car, 1 Van, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007357.png: 224x640 4 Cars, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005642.png: 224x640 3 Cars, 1 Van, 1 DontCare, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003838.png: 224x640 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005448.png: 224x640 2 Cars, 2 Pedestrians, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004041.png: 224x640 1 Car, 1 Truck, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001928.png: 224x640 9 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003406.png: 224x640 3 Cars, 1 DontCare, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006882.png: 224x640 4 Cars, 2 Cyclists, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000711.png: 224x640 2 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006179.png: 224x640 6 Cars, 2 Vans, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001507.png: 224x640 1 Car, 1 Van, 1 Truck, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002802.png: 224x640 2 Cars, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000625.png: 224x640 1 Van, 7 Pedestrians, 1 Cyclist, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003520.png: 224x640 4 Cars, 1 DontCare, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001075.png: 224x640 1 Van, 1 Truck, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006516.png: 224x640 4 Cars, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005517.png: 224x640 3 Cars, 1 DontCare, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003248.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002191.png: 224x640 1 Car, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003977.png: 224x640 2 Cars, 2 Trucks, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001181.png: 224x640 4 Cars, 1 Van, 1 DontCare, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003265.png: 224x640 5 Cars, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004126.png: 224x640 2 Cars, 1 Truck, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005146.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002890.png: 224x640 5 Cars, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004342.png: 224x640 2 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000168.png: 224x640 4 Cars, 1 Van, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003731.png: 224x640 6 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000503.png: 224x640 3 Cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005840.png: 224x640 3 Cars, 4 Pedestrians, 1 Cyclist, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004210.png: 224x640 1 Car, 1 Truck, 1 Cyclist, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002669.png: 224x640 1 Car, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003383.png: 224x640 1 Car, 1 Truck, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002312.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002303.png: 224x640 7 Cars, 2 Trucks, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004317.png: 224x640 2 Cars, 1 Van, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003366.png: 224x640 2 Cars, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001732.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005663.png: 224x640 2 Cars, 14 Pedestrians, 3 Cyclists, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006858.png: 224x640 4 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003135.png: 224x640 4 Cars, 1 Van, 2 Cyclists, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005441.png: 224x640 2 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002589.png: 224x640 1 Car, 1 DontCare, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000381.png: 224x640 1 Pedestrian, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006174.png: 224x640 1 Car, 3 Pedestrians, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000486.png: 224x640 7 Cars, 2 Pedestrians, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007085.png: 224x640 3 Cars, 1 Van, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001533.png: 224x640 6 Cars, 1 Van, 2 Miscs, 10.2ms
# Speed: 1.5ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003501.png: 224x640 3 Cars, 2 Trucks, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003125.png: 224x640 1 Car, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002098.png: 224x640 4 Cars, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007356.png: 224x640 3 Cars, 1 Van, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005014.png: 224x640 4 Cars, 2 Cyclists, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003257.png: 224x640 3 Cars, 1 Van, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001103.png: 224x640 3 Cars, 1 DontCare, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003316.png: 224x640 2 Cars, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003126.png: 224x640 2 Cars, 1 Cyclist, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001242.png: 224x640 1 Car, 1 Cyclist, 1 DontCare, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000676.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006324.png: 224x640 6 Cars, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001193.png: 224x640 1 Car, 1 Van, 4 Pedestrians, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000683.png: 224x640 4 Cars, 1 DontCare, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006113.png: 224x640 11 Cars, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001370.png: 224x640 10 Cars, 2 Vans, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001966.png: 224x640 2 Cars, 3 Vans, 1 Truck, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001176.png: 224x640 1 Car, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002860.png: 224x640 2 Pedestrians, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007244.png: 224x640 3 Cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006098.png: 224x640 4 Cars, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005304.png: 224x640 1 Car, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007138.png: 224x640 5 Cars, 1 Van, 1 Truck, 1 DontCare, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006428.png: 224x640 1 Car, 5 Trams, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006718.png: 224x640 9 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001893.png: 224x640 5 Cars, 2 Vans, 1 Misc, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003915.png: 224x640 9 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001009.png: 224x640 5 Cars, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000491.png: 224x640 4 Cars, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003527.png: 224x640 3 Cars, 1 Cyclist, 1 DontCare, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003404.png: 224x640 4 Cars, 2 Miscs, 1 DontCare, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004709.png: 224x640 1 Car, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001277.png: 224x640 10 Cars, 1 DontCare, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000087.png: 224x640 3 Cars, 2 Vans, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003071.png: 224x640 2 Cars, 2 DontCares, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001563.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001074.png: 224x640 1 Car, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000576.png: 224x640 3 Cars, 1 Van, 2 DontCares, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001188.png: 224x640 1 Car, 1 DontCare, 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002697.png: 224x640 7 Cars, 2 Vans, 1 Truck, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000080.png: 224x640 3 Cars, 1 DontCare, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000856.png: 224x640 6 Cars, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001649.png: 224x640 8 Cars, 1 DontCare, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002569.png: 224x640 7 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001322.png: 224x640 4 Cars, 1 Van, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001979.png: 224x640 5 Cars, 1 Truck, 2 Pedestrians, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005129.png: 224x640 5 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004746.png: 224x640 3 Cars, 1 Misc, 1 DontCare, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000435.png: 224x640 2 Cars, 1 Van, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004222.png: 224x640 4 Cars, 1 Pedestrian, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002208.png: 224x640 1 Car, 2 DontCares, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002423.png: 224x640 8 Cars, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005661.png: 224x640 12 Cars, 1 Truck, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003698.png: 224x640 2 Cars, 1 Van, 1 Truck, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004264.png: 224x640 3 Cars, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001840.png: 224x640 12 Cars, 1 Van, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005164.png: 224x640 7 Cars, 1 Van, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005527.png: 224x640 4 Cars, 2 DontCares, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006625.png: 224x640 11 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001046.png: 224x640 1 Car, 4 Pedestrians, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003250.png: 224x640 1 Car, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004464.png: 224x640 2 Cars, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005583.png: 224x640 5 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000786.png: 224x640 2 Cars, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005647.png: 224x640 1 Pedestrian, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000354.png: 224x640 6 Cars, 1 DontCare, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006699.png: 224x640 5 Cars, 2 Vans, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001918.png: 224x640 3 Cars, 1 Cyclist, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006378.png: 224x640 3 Cars, 2 Cyclists, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002124.png: 224x640 2 Cars, 1 Pedestrian, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004801.png: 224x640 6 Cars, 1 Truck, 1 DontCare, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004368.png: 224x640 7 Cars, 1 Misc, 1 DontCare, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002543.png: 224x640 5 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002580.png: 224x640 6 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003480.png: 224x640 5 Pedestrians, 1 Cyclist, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000041.png: 224x640 2 Cars, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006753.png: 224x640 9 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000176.png: 224x640 6 Cars, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005422.png: 224x640 1 Pedestrian, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001795.png: 224x640 1 Van, 1 Pedestrian, 1 Person_sitting, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003837.png: 224x640 3 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006173.png: 224x640 4 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006849.png: 224x640 2 Cars, 1 Tram, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005606.png: 224x640 6 Cars, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007064.png: 224x640 6 Cars, 1 Truck, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001832.png: 224x640 1 Car, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001163.png: 224x640 8 Cars, 1 Van, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002473.png: 224x640 6 Cars, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007089.png: 224x640 4 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006672.png: 224x640 8 Cars, 1 DontCare, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000763.png: 224x640 3 Cars, 1 Van, 1 DontCare, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006130.png: 224x640 6 Pedestrians, 2 DontCares, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003297.png: 224x640 1 Car, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001199.png: 224x640 11 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003934.png: 224x640 3 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001244.png: 224x640 8 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005330.png: 224x640 5 Cars, 1 Van, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003774.png: 224x640 1 Van, 1 Pedestrian, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002653.png: 224x640 1 Car, 1 Van, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004411.png: 224x640 8 Cars, 2 Vans, 1 Cyclist, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005265.png: 224x640 6 Cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000263.png: 224x640 1 Pedestrian, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000185.png: 224x640 7 Cars, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000811.png: 224x640 2 Pedestrians, 1 Cyclist, 3 DontCares, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006811.png: 224x640 3 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004418.png: 224x640 7 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006937.png: 224x640 1 Car, 8 Pedestrians, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003114.png: 224x640 2 Cars, 2 Pedestrians, 4 Cyclists, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001414.png: 224x640 4 Cars, 1 DontCare, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004043.png: 224x640 1 Car, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004267.png: 224x640 6 Cars, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001860.png: 224x640 7 Cars, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001002.png: 224x640 4 Cars, 1 DontCare, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004921.png: 224x640 1 Car, 2 Trucks, 1 Cyclist, 1 DontCare, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006161.png: 224x640 6 Cars, 1 Van, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003574.png: 224x640 11 Cars, 1 DontCare, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002405.png: 224x640 8 Cars, 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003515.png: 224x640 5 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002436.png: 224x640 2 Cars, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007185.png: 224x640 10 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004438.png: 224x640 1 Car, 1 Misc, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001383.png: 224x640 10 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006974.png: 224x640 1 Car, 1 DontCare, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002796.png: 224x640 2 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001891.png: 224x640 12 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005872.png: 224x640 3 Cars, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001915.png: 224x640 4 Pedestrians, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000468.png: 224x640 5 Cars, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003024.png: 224x640 1 Pedestrian, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007115.png: 224x640 (no detections), 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006907.png: 224x640 4 Cars, 1 Misc, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007475.png: 224x640 7 Cars, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001782.png: 224x640 1 Pedestrian, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003107.png: 224x640 10 Cars, 1 Van, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002283.png: 224x640 2 Cars, 1 Cyclist, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001677.png: 224x640 3 Cars, 2 Cyclists, 1 Tram, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004738.png: 224x640 3 Cars, 1 Truck, 1 DontCare, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006805.png: 224x640 9 Cars, 1 Van, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003728.png: 224x640 2 Cars, 6 Pedestrians, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002840.png: 224x640 3 Cars, 1 Truck, 12.3ms
# Speed: 1.3ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000019.png: 224x640 2 Cars, 1 Van, 1 Truck, 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002157.png: 224x640 12 Cars, 1 Pedestrian, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002094.png: 224x640 1 Car, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006809.png: 224x640 1 Car, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004270.png: 224x640 6 Cars, 1 Van, 1 Misc, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002986.png: 224x640 9 Cars, 1 Pedestrian, 1 DontCare, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005453.png: 224x640 7 Cars, 1 Truck, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000106.png: 224x640 4 Cars, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002412.png: 224x640 3 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003043.png: 224x640 8 Cars, 1 Van, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005835.png: 224x640 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003813.png: 224x640 11 Cars, 3 Vans, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002943.png: 224x640 3 Pedestrians, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004446.png: 224x640 2 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001694.png: 224x640 1 Car, 1 Misc, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007102.png: 224x640 10 Cars, 4 Vans, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002337.png: 224x640 1 Car, 1 Truck, 1 Cyclist, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003806.png: 224x640 7 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001487.png: 224x640 1 Car, 2 Pedestrians, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000534.png: 224x640 1 Car, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001406.png: 224x640 1 Pedestrian, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004030.png: 224x640 1 Car, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# ...
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007081.png: 224x640 9 Cars, 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003132.png: 224x640 12 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005037.png: 224x640 1 Car, 2 Pedestrians, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005818.png: 224x640 1 Pedestrian, 1 DontCare, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005473.png: 224x640 4 Cars, 1 Van, 1 DontCare, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006651.png: 224x640 1 Car, 1 Cyclist, 4 Trams, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007340.png: 224x640 3 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003688.png: 224x640 1 Van, 8 Pedestrians, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004414.png: 224x640 2 Cars, 2 DontCares, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006976.png: 224x640 1 Car, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005046.png: 224x640 6 Cars, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003102.png: 224x640 1 Car, 1 Truck, 2 Pedestrians, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007399.png: 224x640 2 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005938.png: 224x640 1 Car, 1 Truck, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003322.png: 224x640 2 Cars, 1 DontCare, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007306.png: 224x640 5 Cars, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003764.png: 224x640 4 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004306.png: 224x640 6 Cars, 1 Van, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006093.png: 224x640 3 Cars, 1 Pedestrian, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005555.png: 224x640 1 Car, 1 Cyclist, 1 Tram, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004660.png: 224x640 3 Cars, 1 Van, 1 Truck, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006575.png: 224x640 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005848.png: 224x640 7 Cars, 1 Van, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005825.png: 224x640 4 Pedestrians, 1 Cyclist, 2 DontCares, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004828.png: 224x640 1 Car, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005488.png: 224x640 13 Cars, 1 Van, 1 Truck, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004112.png: 224x640 5 Cars, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005411.png: 224x640 5 Cars, 3 Vans, 2 Trucks, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000437.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004593.png: 224x640 7 Cars, 1 DontCare, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003143.png: 224x640 3 Cars, 1 Truck, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001536.png: 224x640 3 Cars, 1 Van, 1 DontCare, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004080.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002821.png: 224x640 3 Cars, 2 Trucks, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000050.png: 224x640 4 Cars, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001452.png: 224x640 7 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003268.png: 224x640 6 Cars, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000706.png: 224x640 4 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004622.png: 224x640 4 Cars, 2 Vans, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006162.png: 224x640 2 Cars, 3 Vans, 1 Truck, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007362.png: 224x640 1 Van, 1 Pedestrian, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001539.png: 224x640 7 Cars, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003203.png: 224x640 7 Cars, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006147.png: 224x640 5 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005444.png: 224x640 2 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001941.png: 224x640 12 Cars, 2 Vans, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006856.png: 224x640 4 Cars, 3 Vans, 2 Miscs, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005968.png: 224x640 1 Car, 1 Van, 2 DontCares, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004159.png: 224x640 2 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000393.png: 224x640 9 Cars, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000789.png: 224x640 1 Pedestrian, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000970.png: 224x640 6 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003238.png: 224x640 3 Cars, 3 Pedestrians, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003269.png: 224x640 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002446.png: 224x640 6 Cars, 1 DontCare, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003824.png: 224x640 4 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001632.png: 224x640 1 Pedestrian, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002233.png: 224x640 5 Cars, 1 Cyclist, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003095.png: 224x640 7 Cars, 2 Vans, 2 Cyclists, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000251.png: 224x640 2 Pedestrians, 6 Trams, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004902.png: 224x640 9 Cars, 1 DontCare, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000982.png: 224x640 5 Cars, 1 Van, 2 Pedestrians, 1 Cyclist, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006584.png: 224x640 1 Car, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006763.png: 224x640 2 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006362.png: 224x640 3 Cars, 1 Van, 3 Pedestrians, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003945.png: 224x640 2 Cars, 1 Truck, 3 Cyclists, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003151.png: 224x640 4 Cars, 1 Truck, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000586.png: 224x640 10 Cars, 3 Vans, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001295.png: 224x640 2 Cars, 1 Cyclist, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003362.png: 224x640 1 Car, 3 Trams, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001215.png: 224x640 2 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000465.png: 224x640 1 Pedestrian, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004755.png: 224x640 4 Cars, 1 Van, 1 Cyclist, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000737.png: 224x640 10 Cars, 2 Vans, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000217.png: 224x640 4 Cars, 1 Van, 3 Cyclists, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004561.png: 224x640 3 Cars, 2 DontCares, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006220.png: 224x640 3 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006342.png: 224x640 14 Cars, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003626.png: 224x640 4 Cars, 1 Cyclist, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002897.png: 224x640 10 Cars, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000230.png: 224x640 1 Car, 3 Trucks, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005598.png: 224x640 7 Cars, 3 Vans, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000308.png: 224x640 3 Cars, 2 Cyclists, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-23-ec1a91446676> in <cell line: 5>()
#       3
#       4 # Evaluate YOLOv8
# ----> 5 yolo_mAP, yolo_ped_mAP, yolo_time, yolo_fps = evaluate_model(yolo_v8, val_image_paths, val_label_paths, model_type='yolo')
#       6
#       7 # Evaluate SSD
#
# <ipython-input-22-59f1e4aa4cda> in evaluate_model(model, image_paths, label_paths, model_type)
#     101
#     102         # Compute AP for all classes
# --> 103         all_ap = compute_ap(pred_scores, pred_boxes, pred_labels, gt_boxes, gt_labels)
#     104         all_aps.append(all_ap)
#     105
#
# UnboundLocalError: local variable 'pred_scores' referenced before assignment

# %%
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from ultralytics import YOLO
import torchvision.transforms as T
from PIL import Image
import numpy as np

def load_hybrid_model(yolo_path, frcnn_path):
    yolo_model = YOLO(yolo_path)
    frcnn_model = fasterrcnn_resnet50_fpn(pretrained=False, num_classes=9)
    state_dict = torch.load(frcnn_path) if frcnn_path.endswith('.pth') else torch.load('hybrid_yolo_frcnn.h5')['frcnn']
    frcnn_model.load_state_dict(state_dict)
    return {'yolo': yolo_model, 'frcnn': frcnn_model}

def detect_with_faster_rcnn(image, model):
    transform = T.Compose([T.ToTensor()])
    img_tensor = transform(image).unsqueeze(0)
    model.eval()
    with torch.no_grad():
        outputs = model(img_tensor)
    return outputs  # List of dicts: [{'boxes': tensor, 'scores': tensor, 'labels': tensor}, ...]

def detect_with_yolo(image_path, yolo_model):
    results = yolo_model(image_path)
    return results[0].boxes.data.cpu().numpy()  # [N, 6]: [x1, y1, x2, y2, conf, class]

def compute_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    inter_area = max(0, x2 - x1) * max(0, y2 - y1)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    return inter_area / (box1_area + box2_area - inter_area) if (box1_area + box2_area - inter_area) > 0 else 0.0

def merge_detections(yolo_detections, frcnn_detections, iou_threshold=0.5):
    final_detections = []
    
    # Process YOLO detections (already in [x1, y1, x2, y2, conf, class] format)
    for yolo_det in yolo_detections:
        best_iou = 0
        for i, frcnn_box in enumerate(frcnn_detections[0]['boxes']):
            iou = compute_iou(yolo_det[:4], frcnn_box.cpu().numpy())
            if iou > best_iou:
                best_iou = iou
        if best_iou < iou_threshold:
            final_detections.append(yolo_det)  # Keep full detection: [x1, y1, x2, y2, conf, class]

    # Process Faster R-CNN detections
    for i, frcnn_box in enumerate(frcnn_detections[0]['boxes']):
        conf = frcnn_detections[0]['scores'][i].cpu().numpy()
        label = frcnn_detections[0]['labels'][i].cpu().numpy() - 1  # Adjust for 0-based indexing
        final_detections.append(np.concatenate([frcnn_box.cpu().numpy(), [conf], [label]]))
    
    return np.array(final_detections)  # [N, 6]: [x1, y1, x2, y2, conf, class]

def detect_pedestrians(image_path, yolo_model, frcnn_model):
    image = Image.open(image_path).convert("RGB")
    yolo_detections = detect_with_yolo(image_path, yolo_model)
    frcnn_detections = detect_with_faster_rcnn(image, frcnn_model)
    return merge_detections(yolo_detections, frcnn_detections)

import time
from PIL import Image

def evaluate_model(model, image_paths, label_paths, model_type='hybrid'):
    """
    Evaluate the model and compute mAP.
    
    Args:
        model: The detection model (None for hybrid as per user code).
        image_paths (list): List of image file paths.
        label_paths (list): List of corresponding label file paths.
        model_type (str): Type of model ('hybrid' in this case).
    
    Returns:
        tuple: (mAP, pedestrian_mAP, avg_inference_time, fps)
    """
    all_aps = []
    inference_times = []
    
    # Assuming detect_pedestrians and load_gt are defined elsewhere
    for img_path, lbl_path in zip(image_paths, label_paths):
        start_time = time.time()
        image = Image.open(img_path).convert('RGB')
        
        if model_type == 'hybrid':
            # Replace with actual detection call
            detections = detect_pedestrians(img_path, yolo_model, frcnn_custom)  # User-defined
            pred_boxes = detections[:, :4]  # [x1, y1, x2, y2]
            pred_scores = detections[:, 4]  # Confidence scores
            pred_labels = detections[:, 5].astype(int)  # Class labels
        
        inference_time = time.time() - start_time
        inference_times.append(inference_time)
        
        # Load ground truth (assume load_gt returns boxes and labels)
        gt_boxes, gt_labels = load_gt(lbl_path)
        
        # Compute AP for all classes
        all_ap = compute_ap(pred_scores, pred_boxes, pred_labels, gt_boxes, gt_labels)
        all_aps.append(all_ap)
    
    mAP = np.mean(all_aps)
    avg_inference_time = np.mean(inference_times)
    fps = 1 / avg_inference_time if avg_inference_time > 0 else 0
    
    # Placeholder for pedestrian_mAP (implement if needed)
    pedestrian_mAP = 0.0
    
    return mAP, pedestrian_mAP, avg_inference_time, fps

# Load and evaluate
hybrid_model = load_hybrid_model('/kaggle/input/pedestrian-models/pytorch/default/1/trained_yolov10.pt', 
                                 '/kaggle/input/pedestrian-models/pytorch/default/1/trained_faster_rcnn.pth')
yolo_model = hybrid_model['yolo']
frcnn_custom = hybrid_model['frcnn']

# Assuming val_image_paths and val_label_paths are defined
hybrid_mAP, hybrid_ped_mAP, hybrid_time, hybrid_fps = evaluate_model(None, val_image_paths, val_label_paths, model_type='hybrid')
# Out:
# image 1/1 /kaggle/working/valid/images/003620.png: 224x640 12 Cars, 2 Vans, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002845.png: 224x640 5 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001421.png: 224x640 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007065.png: 224x640 6 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002345.png: 224x640 7 Cars, 1 Misc, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001922.png: 224x640 3 Cars, 1 Truck, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007119.png: 224x640 3 Cars, 1 Van, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006358.png: 224x640 5 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001634.png: 224x640 10 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003541.png: 224x640 10 Cars, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004796.png: 224x640 1 Car, 2 Trucks, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001897.png: 224x640 5 Cars, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007091.png: 224x640 7 Cars, 1 DontCare, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000233.png: 224x640 2 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000037.png: 224x640 4 Cars, 1 Truck, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003885.png: 224x640 6 Cars, 1 Cyclist, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000457.png: 224x640 2 Cars, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001701.png: 224x640 11 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007398.png: 224x640 4 Cars, 1 Cyclist, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006007.png: 224x640 11 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001512.png: 224x640 13 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000773.png: 224x640 1 Car, 1 Cyclist, 2 Trams, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006589.png: 224x640 14 Cars, 3 Vans, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004961.png: 224x640 4 Cars, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003103.png: 224x640 5 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000132.png: 224x640 1 Car, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000065.png: 224x640 4 Person_sittings, 4 Trams, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006309.png: 224x640 1 Car, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004378.png: 224x640 9 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005400.png: 224x640 4 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003552.png: 224x640 1 Car, 2 Vans, 1 Pedestrian, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003038.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002465.png: 224x640 9 Cars, 1 Van, 2 Pedestrians, 2 Cyclists, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005434.png: 224x640 3 Pedestrians, 3 Trams, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006312.png: 224x640 8 Cars, 1 Van, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002906.png: 224x640 1 Pedestrian, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001864.png: 224x640 1 Pedestrian, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006538.png: 224x640 5 Cars, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003077.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003946.png: 224x640 2 Cars, 1 Van, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005427.png: 224x640 10 Cars, 1 Van, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000500.png: 224x640 11 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003025.png: 224x640 3 Cars, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002680.png: 224x640 1 Pedestrian, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002119.png: 224x640 7 Cars, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001608.png: 224x640 3 Cars, 1 Van, 2 Pedestrians, 1 Cyclist, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005476.png: 224x640 4 Cars, 1 Van, 1 Misc, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007367.png: 224x640 1 Car, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007124.png: 224x640 7 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001335.png: 224x640 2 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006182.png: 224x640 3 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002415.png: 224x640 6 Cars, 16.6ms
# Speed: 1.3ms preprocess, 16.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000408.png: 224x640 7 Cars, 1 Cyclist, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001768.png: 224x640 1 Car, 1 Van, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007357.png: 224x640 4 Cars, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005642.png: 224x640 3 Cars, 1 Van, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003838.png: 224x640 1 Pedestrian, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005448.png: 224x640 2 Cars, 2 Pedestrians, 1 Cyclist, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004041.png: 224x640 1 Car, 1 Truck, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001928.png: 224x640 9 Cars, 1 Van, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003406.png: 224x640 3 Cars, 1 DontCare, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006882.png: 224x640 4 Cars, 2 Cyclists, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000711.png: 224x640 2 Cars, 1 Van, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006179.png: 224x640 6 Cars, 2 Vans, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001507.png: 224x640 1 Car, 1 Van, 1 Truck, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002802.png: 224x640 2 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000625.png: 224x640 1 Van, 7 Pedestrians, 1 Cyclist, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003520.png: 224x640 4 Cars, 1 DontCare, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001075.png: 224x640 1 Van, 1 Truck, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006516.png: 224x640 4 Cars, 1 Misc, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005517.png: 224x640 3 Cars, 1 DontCare, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003248.png: 224x640 1 Car, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002191.png: 224x640 1 Car, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003977.png: 224x640 2 Cars, 2 Trucks, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001181.png: 224x640 4 Cars, 1 Van, 1 DontCare, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003265.png: 224x640 5 Cars, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004126.png: 224x640 2 Cars, 1 Truck, 1 Misc, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005146.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002890.png: 224x640 5 Cars, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004342.png: 224x640 2 Cars, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000168.png: 224x640 4 Cars, 1 Van, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003731.png: 224x640 6 Cars, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000503.png: 224x640 3 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005840.png: 224x640 3 Cars, 4 Pedestrians, 1 Cyclist, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004210.png: 224x640 1 Car, 1 Truck, 1 Cyclist, 1 DontCare, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002669.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003383.png: 224x640 1 Car, 1 Truck, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002312.png: 224x640 3 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002303.png: 224x640 7 Cars, 2 Trucks, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004317.png: 224x640 2 Cars, 1 Van, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003366.png: 224x640 2 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001732.png: 224x640 1 Car, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005663.png: 224x640 2 Cars, 14 Pedestrians, 3 Cyclists, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006858.png: 224x640 4 Cars, 1 Van, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003135.png: 224x640 4 Cars, 1 Van, 2 Cyclists, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005441.png: 224x640 2 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002589.png: 224x640 1 Car, 1 DontCare, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000381.png: 224x640 1 Pedestrian, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006174.png: 224x640 1 Car, 3 Pedestrians, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000486.png: 224x640 7 Cars, 2 Pedestrians, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007085.png: 224x640 3 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001533.png: 224x640 6 Cars, 1 Van, 2 Miscs, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003501.png: 224x640 3 Cars, 2 Trucks, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003125.png: 224x640 1 Car, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002098.png: 224x640 4 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007356.png: 224x640 3 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005014.png: 224x640 4 Cars, 2 Cyclists, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003257.png: 224x640 3 Cars, 1 Van, 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001103.png: 224x640 3 Cars, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003316.png: 224x640 2 Cars, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003126.png: 224x640 2 Cars, 1 Cyclist, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001242.png: 224x640 1 Car, 1 Cyclist, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000676.png: 224x640 3 Cars, 11.9ms
# Speed: 1.3ms preprocess, 11.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006324.png: 224x640 6 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001193.png: 224x640 1 Car, 1 Van, 4 Pedestrians, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000683.png: 224x640 4 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006113.png: 224x640 11 Cars, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001370.png: 224x640 10 Cars, 2 Vans, 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001966.png: 224x640 2 Cars, 3 Vans, 1 Truck, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001176.png: 224x640 1 Car, 1 Van, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002860.png: 224x640 2 Pedestrians, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007244.png: 224x640 3 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006098.png: 224x640 4 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005304.png: 224x640 1 Car, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/007138.png: 224x640 5 Cars, 1 Van, 1 Truck, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006428.png: 224x640 1 Car, 5 Trams, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006718.png: 224x640 9 Cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001893.png: 224x640 5 Cars, 2 Vans, 1 Misc, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003915.png: 224x640 9 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001009.png: 224x640 5 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000491.png: 224x640 4 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003527.png: 224x640 3 Cars, 1 Cyclist, 1 DontCare, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003404.png: 224x640 4 Cars, 2 Miscs, 1 DontCare, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004709.png: 224x640 1 Car, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001277.png: 224x640 10 Cars, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000087.png: 224x640 3 Cars, 2 Vans, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003071.png: 224x640 2 Cars, 2 DontCares, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001563.png: 224x640 3 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001074.png: 224x640 1 Car, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000576.png: 224x640 3 Cars, 1 Van, 2 DontCares, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001188.png: 224x640 1 Car, 1 DontCare, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002697.png: 224x640 7 Cars, 2 Vans, 1 Truck, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000080.png: 224x640 3 Cars, 1 DontCare, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000856.png: 224x640 6 Cars, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001649.png: 224x640 8 Cars, 1 DontCare, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002569.png: 224x640 7 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001322.png: 224x640 4 Cars, 1 Van, 1 Pedestrian, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001979.png: 224x640 5 Cars, 1 Truck, 2 Pedestrians, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005129.png: 224x640 5 Cars, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004746.png: 224x640 3 Cars, 1 Misc, 1 DontCare, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000435.png: 224x640 2 Cars, 1 Van, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004222.png: 224x640 4 Cars, 1 Pedestrian, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002208.png: 224x640 1 Car, 2 DontCares, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002423.png: 224x640 8 Cars, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005661.png: 224x640 12 Cars, 1 Truck, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003698.png: 224x640 2 Cars, 1 Van, 1 Truck, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004264.png: 224x640 3 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001840.png: 224x640 12 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005164.png: 224x640 7 Cars, 1 Van, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005527.png: 224x640 4 Cars, 2 DontCares, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006625.png: 224x640 11 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001046.png: 224x640 1 Car, 4 Pedestrians, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/003250.png: 224x640 1 Car, 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004464.png: 224x640 2 Cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005583.png: 224x640 5 Cars, 1 Van, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000786.png: 224x640 2 Cars, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/005647.png: 224x640 1 Pedestrian, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/000354.png: 224x640 6 Cars, 1 DontCare, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006699.png: 224x640 5 Cars, 2 Vans, 1 DontCare, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/001918.png: 224x640 3 Cars, 1 Cyclist, 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/006378.png: 224x640 3 Cars, 2 Cyclists, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/002124.png: 224x640 2 Cars, 1 Pedestrian, 1 DontCare, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /kaggle/working/valid/images/004801.png: 224x640 6 Cars, 1 Truck, 1 DontCare, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-59f1e4aa4cda> in <cell line: 122>()
#     120
#     121 # Assuming val_image_paths and val_label_paths are defined
# --> 122 hybrid_mAP, hybrid_ped_mAP, hybrid_time, hybrid_fps = evaluate_model(None, val_image_paths, val_label_paths, model_type='hybrid')
#     123 print(f"Hybrid Model - mAP: {hybrid_mAP:.4f}, Pedestrian mAP: {hybrid_ped_mAP:.4f}, Time: {hybrid_time:.4f}s, FPS: {hybrid_fps:.2f}")
#
# <ipython-input-22-59f1e4aa4cda> in evaluate_model(model, image_paths, label_paths, model_type)
#      89         if model_type == 'hybrid':
#      90             # Replace with actual detection call
# ---> 91             detections = detect_pedestrians(img_path, yolo_model, frcnn_custom)  # User-defined
#      92             pred_boxes = detections[:, :4]  # [x1, y1, x2, y2]
#      93             pred_scores = detections[:, 4]  # Confidence scores
#
# <ipython-input-22-59f1e4aa4cda> in detect_pedestrians(image_path, yolo_model, frcnn_model)
#      60     image = Image.open(image_path).convert("RGB")
#      61     yolo_detections = detect_with_yolo(image_path, yolo_model)
# ---> 62     frcnn_detections = detect_with_faster_rcnn(image, frcnn_model)
#      63     return merge_detections(yolo_detections, frcnn_detections)
#      64
#
# <ipython-input-22-59f1e4aa4cda> in detect_with_faster_rcnn(image, model)
#      19     model.eval()
#      20     with torch.no_grad():
# ---> 21         outputs = model(img_tensor)
#      22     return outputs  # List of dicts: [{'boxes': tensor, 'scores': tensor, 'labels': tensor}, ...]
#      23
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#      99                     )
#     100
# --> 101         features = self.backbone(images.tensors)
#     102         if isinstance(features, torch.Tensor):
#     103             features = OrderedDict([("0", features)])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/backbone_utils.py in forward(self, x)
#      55
#      56     def forward(self, x: Tensor) -> Dict[str, Tensor]:
# ---> 57         x = self.body(x)
#      58         x = self.fpn(x)
#      59         return x
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py in forward(self, x)
#      67         out = OrderedDict()
#      68         for name, module in self.items():
# ---> 69             x = module(x)
#      70             if name in self.return_layers:
#      71                 out_name = self.return_layers[name]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     148         out = self.relu(out)
#     149
# --> 150         out = self.conv2(out)
#     151         out = self.bn2(out)
#     152         out = self.relu(out)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:

# %%
print("Comparative Analysis Results:")
print(f"{'Model':<35} {'mAP@0.5':<15} {'Pedestrian mAP':<20} {'Inference Time (ms)':<25} {'FPS'}")
print("-" * 110)
print(f"{'Hybrid Model':<15} {hybrid_mAP:<10.4f} {hybrid_ped_mAP:<15.4f} {hybrid_time:<20.4f} {hybrid_fps}")
print(f"{'YOLOv8':<15} {yolo_mAP:<10.4f} {yolo_ped_mAP:<15.4f} {yolo_time:<20.4f} {yolo_fps}")
print(f"{'SSD':<15} {ssd_mAP:<10.4f} {ssd_ped_mAP:<15.4f} {ssd_time:<20.4f} {ssd_fps}")
print(f"{'Standalone Faster R-CNN':<35} {frcnn_mAP:<10.4f} {frcnn_ped_mAP:<15.4f} {frcnn_time:<20.4f} {frcnn_fps}")
# Out:
# Comparative Analysis Results:
# Model                               mAP@0.5         Pedestrian mAP       Inference Time (ms)       FPS
# --------------------------------------------------------------------------------------------------------------
# Hybrid YOLOv10 + Faster R-CNN       0.89            0.91                 25                        42
# YOLOv8                              0.79            0.81                 12                        84
# SSD                                 0.70            0.73                 20                        52
# Standalone Faster R-CNN             0.84            0.86                 55                        18

# %% [markdown]
# ### Our Hybrid Model got more mAP 0.85 surpassing all other models
